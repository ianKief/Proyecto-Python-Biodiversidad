# %%
import sys
import csv
from pathlib import Path

sys.path.append(str(Path.cwd().parent))
import src.validacion as validacion

# %%
validacion.coordenadas("xeno-canto-bird-sounds-filtered","Occurrence.txt")
validacion.coordenadas("Colección-Ornitológica-del-IADIZA-CCT-CONICET-Mendoza-IADIZA-COI","occurrence.txt","\t")
validacion.coordenadas("inaturalist-filtered","observations.csv")
# Out:
# xeno-canto-bird-sounds-filtered
# en el dataset: xeno-canto-bird-sounds-filtered hay 2418 coordenadas invalidas
#
#
# Colección-Ornitológica-del-IADIZA-CCT-CONICET-Mendoza-IADIZA-COI
# en el dataset: Colección-Ornitológica-del-IADIZA-CCT-CONICET-Mendoza-IADIZA-COI  el campo decimalLatitude y decimalLongitude estan completamente vacios
# en el dataset: Colección-Ornitológica-del-IADIZA-CCT-CONICET-Mendoza-IADIZA-COI hay 2370 coordenadas invalidas
#
#
# inaturalist-filtered
# en el dataset: inaturalist-filtered hay 2 coordenadas invalidas
# ([{'id': '999990001',
#    'occurrenceID': 'https://www.inaturalist.org/observations/42369866',
#    'basisOfRecord': 'HumanObservation',
#    'modified': '2020-10-27T19:46:33Z',
#    'institutionCode': 'iNaturalist',
#    'collectionCode': 'Observations',
#    'datasetName': 'iNaturalist research-grade observations',
#    'informationWithheld': '',
#    'catalogNumber': '42369866',
#    'references': 'https://www.inaturalist.org/observations/42369866',
#    'occurrenceRemarks': '',
#    'recordedBy': 'Pablo H Capovilla',
#    'recordedByID': '',
#    'identifiedBy': 'Pablo H Capovilla',
#    'identifiedByID': '',
#    'captive': 'wild',
#    'eventDate': '2018-03-31T08:09:00-03:00',
#    'eventTime': '08:09:00-03:00',
#    'verbatimEventDate': '2018/03/31 8:09 AM -0300',
#    'verbatimLocality': 'Gral Obligado, Santa Fe, Argentina',
#    'decimalLatitude': '95.1234',
#    'decimalLongitude': '-59.2650',
#    'coordinateUncertaintyInMeters': '15',
#    'geodeticDatum': 'EPSG:4326',
#    'countryCode': 'AR',
#    'stateProvince': 'Santa Fe',
#    'identificationID': '95899387',
#    'dateIdentified': '2020-04-17T04:09:14Z',
#    'identificationRemarks': '',
#    'taxonID': '15764',
#    'scientificName': 'Thamnophilus doliatus',
#    'taxonRank': 'species',
#    'kingdom': 'Animalia',
#    'phylum': 'Chordata',
#    'class': 'Aves',
#    'order': 'Passeriformes',
#    'family': 'Thamnophilidae',
#    'genus': 'Thamnophilus',
#    'license': 'https://creativecommons.org/licenses/by/4.0/',
#    'rightsHolder': 'Pablo H Capovilla',
#    'inaturalistLogin': 'pablohcapovilla',
#    'publishingCountry': 'AR',
#    'projectId': '',
#    'sex': 'male',
#    'lifeStage': 'adult',
#    'reproductiveCondition': '',
#    'vitality': 'alive',
#    'dynamicProperties': ''},
#   {'id': '999990002',
#    'occurrenceID': 'https://www.inaturalist.org/observations/42369866',
#    'basisOfRecord': 'HumanObservation',
#    'modified': '2020-10-27T19:46:33Z',
#    'institutionCode': 'iNaturalist',
#    'collectionCode': 'Observations',
#    'datasetName': 'iNaturalist research-grade observations',
#    'informationWithheld': '',
#    'catalogNumber': '42369866',
#    'references': 'https://www.inaturalist.org/observations/42369866',
#    'occurrenceRemarks': '',
#    'recordedBy': 'Pablo H Capovilla',
#    'recordedByID': '',
#    'identifiedBy': 'Pablo H Capovilla',
#    'identifiedByID': '',
#    'captive': 'wild',
#    'eventDate': '2018-03-31T08:09:00-03:00',
#    'eventTime': '08:09:00-03:00',
#    'verbatimEventDate': '2018/03/31 8:09 AM -0300',
#    'verbatimLocality': 'Gral Obligado, Santa Fe, Argentina',
#    'decimalLatitude': '-28.5015',
#    'decimalLongitude': '200.4567',
#    'coordinateUncertaintyInMeters': '15',
#    'geodeticDatum': 'EPSG:4326',
#    'countryCode': 'AR',
#    'stateProvince': 'Santa Fe',
#    'identificationID': '95899387',
#    'dateIdentified': '2020-04-17T04:09:14Z',
#    'identificationRemarks': '',
#    'taxonID': '15764',
#    'scientificName': 'Thamnophilus doliatus',
#    'taxonRank': 'species',
#    'kingdom': 'Animalia',
#    'phylum': 'Chordata',
#    'class': 'Aves',
#    'order': 'Passeriformes',
#    'family': 'Thamnophilidae',
#    'genus': 'Thamnophilus',
#    'license': 'https://creativecommons.org/licenses/by/4.0/',
#    'rightsHolder': 'Pablo H Capovilla',
#    'inaturalistLogin': 'pablohcapovilla',
#    'publishingCountry': 'AR',
#    'projectId': '',
#    'sex': 'male',
#    'lifeStage': 'adult',
#    'reproductiveCondition': '',
#    'vitality': 'alive',
#    'dynamicProperties': ''}],
#  2)
