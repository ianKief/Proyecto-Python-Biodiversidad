# %%
import sys
sys.path.append('../src')
import validacion

# %%
validacion.coordenadas("xeno-canto-bird-sounds-filtered","occurrence.txt")
validacion.coordenadas("Colección-Ornitológica-del-IADIZA-CCT-CONICET-Mendoza-IADIZA-COI","occurrence.txt","\t")
validacion.coordenadas("inaturalist-filtered","observations.csv")

# %%
validacion.existe("xeno-canto-bird-sounds-filtered","occurrence.txt")
validacion.existe("Colección-Ornitológica-del-IADIZA-CCT-CONICET-Mendoza-IADIZA-COI","occurrence.txt","\t")
validacion.existe("inaturalist-filtered","observations.csv")

# %%
validacion.fechas("xeno-canto-bird-sounds-filtered","occurrence.txt")
validacion.fechas("Colección-Ornitológica-del-IADIZA-CCT-CONICET-Mendoza-IADIZA-COI","occurrence.txt","\t")
validacion.fechas("inaturalist-filtered","observations.csv")

# %%
validacion.duplicados("xeno-canto-bird-sounds-filtered","Occurrence.txt")
validacion.duplicados("Colección-Ornitológica-del-IADIZA-CCT-CONICET-Mendoza-IADIZA-COI","occurrence.txt","\t")
validacion.duplicados("inaturalist-filtered","observations.csv")

# %%
validacion.country("xeno-canto-bird-sounds-filtered","Occurrence.txt")
validacion.country("Colección-Ornitológica-del-IADIZA-CCT-CONICET-Mendoza-IADIZA-COI","occurrence.txt","\t")
validacion.country("inaturalist-filtered","observations.csv")

# %%
validacion.incertidumbre("xeno-canto-bird-sounds-filtered","occurrence.txt")
validacion.incertidumbre("Colección-Ornitológica-del-IADIZA-CCT-CONICET-Mendoza-IADIZA-COI","occurrence.txt","\t")
validacion.incertidumbre("inaturalist-filtered","observations.csv")

# %%
validacion.resumen("xeno-canto-bird-sounds-filtered","occurrence.txt")
validacion.resumen("Colección-Ornitológica-del-IADIZA-CCT-CONICET-Mendoza-IADIZA-COI","occurrence.txt","\t")
validacion.resumen("inaturalist-filtered","observations.csv")

# %%
validacion.max_min("xeno-canto-bird-sounds-filtered","occurrence.txt")
validacion.max_min("Colección-Ornitológica-del-IADIZA-CCT-CONICET-Mendoza-IADIZA-COI","occurrence.txt","\t")
validacion.max_min("inaturalist-filtered","observations.csv")

# %%
validacion.coordenada_completa("xeno-canto-bird-sounds-filtered","occurrence.txt","latitude",90,-90)
validacion.coordenada_completa("Colección-Ornitológica-del-IADIZA-CCT-CONICET-Mendoza-IADIZA-COI","occurrence.txt","latitude",90,-90,"\t")
validacion.coordenada_completa("inaturalist-filtered","observations.csv","latitude",90,-90)

validacion.coordenada_completa("xeno-canto-bird-sounds-filtered","occurrence.txt","longitude",180,-180)
validacion.coordenada_completa("Colección-Ornitológica-del-IADIZA-CCT-CONICET-Mendoza-IADIZA-COI","occurrence.txt","longitude",180,-180,"\t")
validacion.coordenada_completa("inaturalist-filtered","observations.csv","longitude",180,-180)
