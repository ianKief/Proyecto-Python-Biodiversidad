# %%
import sys
import os
raiz = os.path.abspath('..')
if raiz not in sys.path:
    sys.path.append(raiz)
from src import eliminacion

# %% [markdown]
# **Pruebas de la funcion de eliminacion por ID**

# %%
eliminacion.identificador("iadiza", "occurrence.txt", "1", "\t")

# %%
eliminacion.identificador("iadiza", "occurrence.txt", "1660908054", "\t")

# %% [markdown]
# **Pruebas de la función de eliminación por columna recibida por parámetro**

# %%
eliminacion.eliminar_columna("iadiza", "occurrence.txt", "gbifID", ["1660908054"], "\t")

# %%
eliminacion.eliminar_columna("iadiza", "occurrence.txt", "gbifID", ["1"], "\t")

# %% [markdown]
# **Pruebas de la función de eliminación por alguna condición en particular**

# %%
eliminacion.condicion("iadiza", "occurrence.txt", "gbifID", "1660908042", "Igual", "\t")

# %% [markdown]
# **Pruebas de la funcion de sanitizar**

# %%
eliminacion.sanitizar("iadiza", "occurrence.txt", "\t")
