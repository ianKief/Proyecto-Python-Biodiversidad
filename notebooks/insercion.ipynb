# %%
import sys
sys.path.append('../src')
import insercion

# %%
estructura_iadiza = crear_estructura_registro("iadiza", "occurrence.txt", "\t")
print(estructura_iadiza)

estructura_inaturalist = crear_estructura_registro("inaturalist", "observations.csv")
print(estructura_inaturalist)

estructura_xeno = crear_estructura_registro("xeno", "Occurrence.txt")
print(estructura_xeno)

# %%
registro_iadiza = generar_registro_vacio(estructura_iadiza)
print(registro_iadiza)

registro_inaturalist = generar_registro_vacio(estructura_inaturalist)
print(registro_inaturalist)

registro_xeno = generar_registro_vacio(estructura_xeno)
print(registro_xeno)

# %%
registro_iadiza_preparado = preparar_registro_para_csv("iadiza","occurrence.txt",registro_iadiza,estructura_iadiza,"\t")
print(registro_iadiza_preparado)

registro_inaturalist_preparado = preparar_registro_para_csv("inaturalist","observations.csv",registro_inaturalist,estructura_inaturalist)
print(registro_inaturalist_preparado)

registro_xeno_preparado = preparar_registro_para_csv("xeno","Occurrence.txt",registro_xeno,estructura_xeno,)
print(registro_xeno_preparado)

# %%
insertar_multiples_registros("iadiza", "occurrence.txt", "\t")

# %%
insertar_multiples_registros("xeno", "Occurrence.txt")

# %%
insertar_multiples_registros("inaturalist", "observations.csv")
