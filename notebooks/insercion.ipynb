# %% [markdown]
# ## Ejercicio 4 - Insercion de registros en datasets

# %%
import sys
sys.path.append('../src')
import insercion

# %% [markdown]
# ## 4.A - Estructura de un registro Darwin Core

# %%
estructura_iadiza = crear_estructura_registro("iadiza", "occurrence.txt")
print(estructura_iadiza)

estructura_inaturalist = crear_estructura_registro("inaturalist", "observations.csv")
print(estructura_inaturalist)

estructura_xeno = crear_estructura_registro("xeno", "occurrence.txt")
print(estructura_xeno)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 estructura_iadiza = crear_estructura_registro("iadiza", "occurrence.txt")
#       2 print(estructura_iadiza)
#
# NameError: name 'crear_estructura_registro' is not defined
