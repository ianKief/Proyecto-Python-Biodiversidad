# %% [markdown]
# # Lectura
#
# ### Modulo que se encarga de la lectura y procesamiento de la informacion de un dataset
#
# ### En este notebook se realizaran pruebas para las distintas funciones del modulo

# %%
import sys
import os
raiz = os.path.abspath('..')
if raiz not in sys.path:
    sys.path.append(raiz)
from src import lectura

# %% [markdown]
# **Funcion que retorna un DataFrame con las primeras 10 filas del archivo ingresado:**

# %%
lectura.primeras_10_filas("iadiza", "occurrence.txt","\t")

# %% [markdown]
# **Funcion que retorna un listado con las columnas del dataset ingresado:**

# %%
lectura.listar_columnas("iadiza","occurrence.txt","\t")

# %% [markdown]
# **Funcion que retorna un diccionario de tipo { indice: nombre columna }:**

# %%
lectura.posicion_columnas("inaturalist","observations.csv")

# %% [markdown]
# **Funcion que retorna un entero correspondiente a la cantidad de registros del archivo ingresado:**

# %%
lectura.cant_registros("iadiza","occurrence.txt","\t")

# %% [markdown]
# **Funcion que retorna un diccionario de tipo:**

# %% [markdown]
# **{ cantidad nulos por columna: { columna: cant nulos},
#           promedio nulos por columna: { columna: promedio nulos},
#           columnas totalmente nulas: list}**

# %%
lectura.analisis_nulos("iadiza","occurrence.txt","\t")

# %% [markdown]
# **Funcion que retorna un diccionario de tipo:**

# %% [markdown]
# **{ cant valores distintos columna ingresada: int,
#      frecuencias: { valor: cant repeticiones } }**

# %%
lectura.analisis_frecuencias("iadiza","occurrence.txt","recordedBy","\t")

# %% [markdown]
# **Prueba de los distintos casos de la funcion de valores maximos y minimos**

# %% [markdown]
# **Esta funcion revisa la columna ingresada y su tipo. Si ambos parametros son validos, retorna dependiento el tipo:**

# %% [markdown]
# - **numeric: valor minimo, valor maximo y promedio**
# - **text: texto mas corto y texto mas largo (segun la cantidad de caracteres)**
# - **coordinate: coordenada mas baja y coordenada mas alta (segun el formato DD --> 41.40338,-2.17403)**

# %%
lectura.valores_max_min("iadiza","occurrence.txt","year","numeric","\t")

# %%
lectura.valores_max_min("xeno-canto","Occurrence.txt","collectionCode","text")

# %%
lectura.valores_max_min("xeno-canto","Occurrence.txt","longitudeDecimal","coordinate")

# %%
lectura.valores_max_min("xeno canto","Occurrence.txt","longitudeDecimal","coordinate")

# %%
lectura.valores_max_min("xeno-canto","Occurrence.txt","longitude","coordinate")

# %%
lectura.valores_max_min("xeno-canto","Occurrence.txt","longitudeDecimal","coordenada")

# %%
lectura.valores_max_min("iadiza","occurrence.txt","catalogNumber","numeric","\t")
